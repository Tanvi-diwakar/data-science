# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanvi-diwakar/data-science/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Day 1

# %%
print("hello world")
# Out:
# hello world

# %%
#this is comment for the day

print("good morning")
# Out:
# good morning

# %%
# variable, function, control statement, loops, data types, error handeling,

# there is a certain way to writing programming language- syntax

# SYNTAX- there are certain way of writing syntax

#1. VARIABLES- container that holds data in it and you can perform different programs -> DATA--
# DATA TYPES (numbers, string, list, dictionary, tuples, boolean(0/1))
"""

#2. Function - An essential concept in programming !

4 steps - performed everytime BOT needs to wash an utensil

20 utensils !

option 1:  write 4 lines code everytime you expect BOT to wash one utensil: Total lines of code 20 x 4 = 80

option 2: write 4 lines of code in a function andthen call the function whenever you want BOT to wash. 4 + 1(with a loop) Total 5

we declare a function - we give it a name - then we call it wherever we want that task to be done.

"""
# Out:
# '\n\n#2. Function - An essential concept in programming !\n\n4 steps - performed everytime BOT needs to wash an utensil\n\n20 utensils !\n\noption 1:  write 4 lines code everytime you expect BOT to wash one utensil: Total lines of code 20 x 4 = 80\n\noption 2: write 4 lines of code in a function andthen call the function whenever you want BOT to wash. 4 + 1(with a loop) Total 5\n\nwe declare a function - we give it a name - then we call it wherever we want that task to be done.\n\n'

# %%
def greet():
  print ("Hello everyone, I hope you had a good day")


greet()
# Out:
# Hello everyone, I hope you had a good day
